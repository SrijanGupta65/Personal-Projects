# %% [markdown]
# # 04: Dosage Support Testing
#
# Test medication recommendation and dosage adjustment logic.
#
# Goals:
# - Extract medication patterns from similar patients
# - Apply dosage adjustments based on patient factors
# - Test recommendation pipeline end-to-end

# %%
import pandas as pd
import numpy as np
import re

# %%
# Load data
# df = pd.read_csv('../data/raw/patient_data.csv')
# query_idx = 0
# query_patient = df.iloc[query_idx]
# similar_indices = [1, 3, 5, 7, 9]  # Example similar patient indices
# similar_patients = df.iloc[similar_indices]

# %%
# Extract medications from similar patients
# def extract_medications(dosage_string):
#     """Parse medication and dosage from medication string."""
#     # Simple parsing; adapt to your data format
#     meds = {}
#     # Example: "Metformin 500mg, Lisinopril 10mg"
#     return meds
#
# all_meds = {}
# for idx, row in similar_patients.iterrows():
#     meds = extract_medications(row['Medication_Dosage_Fixed_Period'])
#     for med_name, dosage in meds.items():
#         if med_name not in all_meds:
#             all_meds[med_name] = []
#         all_meds[med_name].append(dosage)
# 
# print(f"Medications recommended for similar patients:")
# for med, dosages in all_meds.items():
#     print(f"{med}: {dosages} (mean: {np.mean(dosages):.1f})")

# %%
# Check allergies
# allergies = query_patient['Medication_Allergies']
# print(f"\nPatient allergies: {allergies}")
# print(f"\nSafety check:")
# for med in all_meds.keys():
#     if allergies and med.lower() in allergies.lower():
#         print(f"  {med}: ALLERGIC - DO NOT RECOMMEND")
#     else:
#         print(f"  {med}: Safe to consider")

# %%
# Dosage adjustment based on patient factors
# standard_weight = 70  # kg
# weight_adjustment = query_patient['Weight_kg'] / standard_weight
# 
# print(f"\nDosage adjustments for {query_patient['Patient_ID']}:")
# print(f"Weight: {query_patient['Weight_kg']} kg (adjustment factor: {weight_adjustment:.2f})")
# print(f"Age: {query_patient['Age']} years")
# print(f"eGFR: {query_patient['eGFR_mL_min']} (kidney function)")
# 
# adjusted_meds = {}
# for med, dosages in all_meds.items():
#     base_dosage = np.mean(dosages)
#     adjusted_dosage = base_dosage * weight_adjustment
#     adjusted_meds[med] = adjusted_dosage
# 
# print(f"\nAdjusted recommendations:")
# for med, adj_dose in adjusted_meds.items():
#     print(f"{med}: {adj_dose:.1f} mg")
